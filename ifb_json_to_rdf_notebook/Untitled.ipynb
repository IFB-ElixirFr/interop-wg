# %%
import requests

# %%
TIMEOUT = (10, 300)

# %%
def requestsIFB():
    url = "https://www.france-bioinformatique.fr/fr/node/286/node_export/json"
    while True:
        try:
            response = requests.get(url, timeout=TIMEOUT)
            break
        except SSLError:
            time.sleep(5)
        except requests.exceptions.Timeout:
            time.sleep(5)

    return response.text

# %%
print(requestsIFB())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN"
#   "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="fr" version="XHTML+RDFa 1.0" dir="ltr">
#
# <head profile="http://www.w3.org/1999/xhtml/vocab">
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta content="width=device-width,initial-scale=1" name="viewport" />
# <link rel="shortcut icon" href="https://www.france-bioinformatique.fr/sites/all/themes/IFB_3/favicon.ico" type="image/vnd.microsoft.icon" />
# <meta name="generator" content="Drupal 7 (http://drupal.org)" />
# <link rel="canonical" href="https://www.france-bioinformatique.fr/fr" />
# <link rel="shortlink" href="https://www.france-bioinformatique.fr/fr" />
#   <title>Accès refusé | IFB</title>
#   <style type="text/css" media="all">
# @import url("https://www.france-bioinformatique.fr/modules/system/system.base.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/system/system.menus.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/system/system.messages.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/system/system.theme.css?pteex4");
# </style>
# <style type="text/css" media="all">
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/simplenews/simplenews.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/CUSTOM/bioschemas_crawler/crawler.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/calendar/css/calendar_multiday.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/collapsiblock/collapsiblock.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/colorbox_node/colorbox_node.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/comment/comment.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/date/date_api/date.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/date/date_popup/themes/datepicker.1.7.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/field/theme/field.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/node/node.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/poll/poll.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/search/search.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/user/user.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/views/css/views.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/ckeditor/css/ckeditor.css?pteex4");
# </style>
# <style type="text/css" media="all">
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/colorbox/styles/default/colorbox_style.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/ctools/css/ctools.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/biblio/biblio.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/modules/locale/locale.css?pteex4");
# </style>
# <link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.4.0/css/font-awesome.min.css" media="all" />
# <style type="text/css" media="all">
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/tb_megamenu/css/bootstrap.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/tb_megamenu/css/base.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/tb_megamenu/css/default.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/tb_megamenu/css/compatibility.css?pteex4");
# </style>
# <style type="text/css" media="all">
# <!--/*--><![CDATA[/*><!--*/
# .tb-megamenu.animate .mega > .mega-dropdown-menu,.tb-megamenu.animate.slide .mega > .mega-dropdown-menu > div{transition-delay:100ms;-webkit-transition-delay:100ms;-ms-transition-delay:100ms;-o-transition-delay:100ms;transition-duration:400ms;-webkit-transition-duration:400ms;-ms-transition-duration:400ms;-o-transition-duration:400ms;}
# #search-block-form .form-item-search-block-form input.form-text{color:#444}
#
# /*]]>*/-->
# </style>
# <style type="text/css" media="all">
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/flexslider/assets/css/flexslider_img.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/libraries/flexslider/flexslider.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/modules/better_search/css/increase_icon_size.css?pteex4");
# </style>
# <style type="text/css" media="all">
# @import url("https://www.france-bioinformatique.fr/sites/all/themes/IFB_3/css/style_ifb.css?pteex4");
# @import url("https://www.france-bioinformatique.fr/sites/all/themes/IFB_3/css/ifb_custom.css?pteex4");
# </style>
#
# <!--[if lte IE 7]>
# <link type="text/css" rel="stylesheet" href="https://www.france-bioinformatique.fr/sites/all/themes/IFB_3/css/ie.css?pteex4" media="all" />
# <![endif]-->
#
# <!--[if IE 6]>
# <link type="text/css" rel="stylesheet" href="https://www.france-bioinformatique.fr/sites/all/themes/IFB_3/css/ie6.css?pteex4" media="all" />
# <![endif]-->
#   <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/jquery_update/replace/jquery/1.5/jquery.min.js?v=1.5.2"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/misc/jquery-extend-3.4.0.js?v=1.5.2"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/misc/jquery.once.js?v=1.2"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/misc/drupal.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/jquery_update/replace/ui/external/jquery.cookie.js?v=67fb34f6a866c40d0570"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/misc/form.js?v=7.67"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/misc/ajax.js?v=7.67"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/jquery_update/js/jquery_update.js?v=0.0.1"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/admin_menu/admin_devel/admin_devel.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/collapsiblock/collapsiblock.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/default/files/languages/fr_I_VzDP62H5HQMU5HfqUQPRzaHk-J7-4dEOmBawjqujo.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/libraries/colorbox/jquery.colorbox-min.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/colorbox/js/colorbox.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/colorbox/styles/default/colorbox_style.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/colorbox/js/colorbox_load.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/colorbox/js/colorbox_inline.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/tb_megamenu/js/tb-megamenu-frontend.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/tb_megamenu/js/tb-megamenu-touch.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/libraries/flexslider/jquery.flexslider-min.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/google_analytics/googleanalytics.js?pteex4"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", "UA-70616345-1", {"cookieDomain":"auto"});ga("set", "page", "/403.html?page=" + document.location.pathname + document.location.search + "&from=" + document.referrer);ga("send", "pageview");
# //--><!]]>
# </script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/misc/collapse.js?v=7.67"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/misc/progress.js?v=7.67"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/colorbox_node/colorbox_node.js?pteex4"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"fr\/","ajaxPageState":{"theme":"IFB_3","theme_token":"zlxCWAAccJFz-13LgMGB5OMST-jcBwLveje4jT_MA8g","jquery_version":"1.5","js":{"sites\/all\/themes\/IFB_3\/js\/site.js":1,"sites\/all\/modules\/flexslider\/assets\/js\/flexslider.load.js":1,"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.5\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"misc\/form.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/modules\/admin_menu\/admin_devel\/admin_devel.js":1,"sites\/all\/modules\/collapsiblock\/collapsiblock.js":1,"public:\/\/languages\/fr_I_VzDP62H5HQMU5HfqUQPRzaHk-J7-4dEOmBawjqujo.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox_load.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox_inline.js":1,"sites\/all\/modules\/tb_megamenu\/js\/tb-megamenu-frontend.js":1,"sites\/all\/modules\/tb_megamenu\/js\/tb-megamenu-touch.js":1,"sites\/all\/libraries\/flexslider\/jquery.flexslider-min.js":1,"sites\/all\/modules\/google_analytics\/googleanalytics.js":1,"0":1,"misc\/collapse.js":1,"misc\/progress.js":1,"sites\/all\/modules\/colorbox_node\/colorbox_node.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/modules\/simplenews\/simplenews.css":1,"sites\/all\/modules\/CUSTOM\/bioschemas_crawler\/crawler.css":1,"sites\/all\/modules\/calendar\/css\/calendar_multiday.css":1,"sites\/all\/modules\/collapsiblock\/collapsiblock.css":1,"sites\/all\/modules\/colorbox_node\/colorbox_node.css":1,"modules\/comment\/comment.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/poll\/poll.css":1,"modules\/search\/search.css":1,"sites\/all\/modules\/CUSTOM\/SFBI\/custom.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/biblio\/biblio.css":1,"modules\/locale\/locale.css":1,"https:\/\/cdnjs.cloudflare.com\/ajax\/libs\/font-awesome\/4.4.0\/css\/font-awesome.min.css":1,"sites\/all\/modules\/tb_megamenu\/css\/bootstrap.css":1,"sites\/all\/modules\/tb_megamenu\/css\/base.css":1,"sites\/all\/modules\/tb_megamenu\/css\/default.css":1,"sites\/all\/modules\/tb_megamenu\/css\/compatibility.css":1,"0":1,"1":1,"sites\/all\/modules\/flexslider\/assets\/css\/flexslider_img.css":1,"sites\/all\/libraries\/flexslider\/flexslider.css":1,"sites\/all\/modules\/better_search\/css\/increase_icon_size.css":1,"sites\/all\/themes\/IFB_3\/css\/style_ifb.css":1,"sites\/all\/themes\/IFB_3\/css\/ifb_custom.css":1,"sites\/all\/themes\/IFB_3\/css\/ie.css":1,"sites\/all\/themes\/IFB_3\/css\/ie6.css":1}},"collapsiblock":{"blocks":{"block-user-login":"4","block-search-form":"1","block-block-11":"1","block-block-5":"1","block-imageblock-2":"1","block-block-7":"1","block-views-calendar-block-1":"1","block-quicktabs-services-en":"1","block-quicktabs-services":"1","block-views-formations-block-1":"1","block-views-workgroups-block-1":"1","block-views-utilisateur-email-block":"1","block-locale-language-content":"1","block-menu-block-1":"1","block-quicktabs-plateformes":"1","block-quicktabs-plateforme":"1","block-block-1":"1","block-block-2":"1","block-gmap-location-0":"1","block-views-poles-regionaux-block-1":"1","block-views-fr-poles-regionaux-block-1":"1","block-views-carte-block-1":"1" ...
# //--><!]]>
# </script>
# </head>
# <body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-286 page-node-node-export page-node-node-export-json i18n-fr node 286 node-export json" >
#   <div id="skip-link">
#     <a href="#main-content" class="element-invisible element-focusable">Aller au contenu principal</a>
#   </div>
#
#
# <header class="navbar navbar-default navbar-fixed-top">
#  <div class="container">
#           <div class="row no-gutter">
#             <div class="col-md-2 col-xs-4 navbar-header">
#                               <a href="/fr" title="Accueil" rel="home" id="logo" class="navbar-brand">
#                   <img src="https://www.france-bioinformatique.fr/sites/default/files/logo-ifb_RVB.jpg" alt="Accueil" />
#                                                   <span  class="element-invisible">
#                     Institut Français de Bioinformatique                  </span>
#                 </a>
#                           </div>
#
#             <nav class="col-md-10 col-xs-8 navbar-right" role="navigation">
#               <div class="clearfix">  <div class="region region-header">
#     <div id="block-block-1" class="block block-block">
#
#
#   <div class="content">
#     <p><a href="/fr/guichet-dorientation">Contact </a></p>
#   </div>
# </div>
# <div id="block-locale-language" class="block block-locale">
#
#
#   <div class="content">
#     <ul class="language-switcher-locale-url"><li class="en first"><a href="/en/node/286/node_export/json" class="language-link" xml:lang="en">EN</a></li>
# <li class="fr last active"><a href="/fr/node/286/node_export/json" class="language-link active" xml:lang="fr">FR</a></li>
# </ul>  </div>
# </div>
# <div id="block-user-login" class="block block-user">
#
#     <h2 class="element-invisible">Connexion</h2>
#
#   <div class="content">
#     <form action="/fr/node/286/node_export/json?destination=node/286/node_export/json" method="post" id="user-login-form" accept-charset="UTF-8"><div><div class="form-item form-type-textfield form-item-name">
#   <label for="edit-name">E-mail or username <span class="form-required" title="Ce champ est requis.">*</span></label>
#  <input type="text" id="edit-name" name="name" value="" size="15" maxlength="60" class="form-text required" />
# </div>
# <div class="form-item form-type-password form-item-pass">
#   <label for="edit-pass">Mot de passe <span class="form-required" title="Ce champ est requis.">*</span></label>
#  <input type="password" id="edit-pass" name="pass" size="15" maxlength="128" class="form-text required" />
# </div>
# <div class="item-list"><ul><li class="first last"><a href="/fr/user/password" title="Demander un nouveau mot de passe par courriel.">Demander un nouveau mot de passe</a></li>
# </ul></div><input type="hidden" name="form_build_id" value="form-n0BfQLySOrevJf9pGluJJi2f5UdLiYR_u-TkNgdSBgU" />
# <input type="hidden" name="form_id" value="user_login_block" />
# <div class="form-actions form-wrapper" id="edit-actions"><input type="submit" id="edit-submit" name="op" value="Se connecter" class="form-submit" /></div></div></form>  </div>
# </div>
#   </div>
# </div>
#                 <div class="region region-header-dessous">
#     <div id="block-tb-megamenu-menu-menu-header-niveau-1" class="block block-tb-megamenu">
#
#
#   <div class="content">
#     <div  data-duration="400" data-delay="100" id="tb-megamenu-menu-menu-header-niveau-1" class="tb-megamenu tb-megamenu-menu-menu-header-niveau-1 animate slide">
#       <button data-target=".nav-collapse" data-toggle="collapse" class="btn btn-navbar tb-megamenu-button" type="button">
#       <i class="fa fa-reorder"></i>
#     </button>
#     <div class="nav-collapse  always-show">
#     <ul  class="tb-megamenu-nav nav level-0 items-13">
#   <li  data-id="4215" data-level="1" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="left" data-group="0" data-hidewcol="0" data-hidesub="0" class="tb-megamenu-item level-1 mega mega-align-left dropdown">
#   <a href="/fr/presentation"  class="dropdown-toggle" title="à propos de nous">
#
#     à propos de nous          <span class="caret"></span>
#           </a>
#   <div  data-class="" data-width="800" style="width: 800px;" class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child">
#   <div class="mega-dropdown-inner">
#     <div  class="tb-megamenu-row row-fluid">
#   <div  data-showblocktitle="1" data-class="" data-width="6" data-hidewcol="" id="tb-megamenu-column-1" class="tb-megamenu-column span6  mega-col-nav">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#         <div  data-type="block" data-block="block--25" class="tb-megamenu-block tb-block tb-megamenu-block">
#   <div class="block-inner">
#     <div id="block-block-25" class="block block-block">
#
#
#   <div class="content">
#
# <div class="sous-menu sous-menu--apropos_structure"><a href="/fr/presentation/structure">Structure</a>
# <!--<p>Organisées en 6 pôles régionaux</p>-->
#
# <ul>
# 	<li><a href="/fr/core">IFB-Core</a></li>
#         <li><a href="/fr/trombi">Equipe IFB-core</a></li>
# 	<li><a href="/fr/partners">Partenaires</a></li>
# 	<li><a href="/fr/presentation/gouvernance">Gouvernance</a></li>
# </ul>
# </div>
#
# <div class="sous-menu sous-menu--apropos_communaute"><a href="/fr/plateformes">Plateformes</a>
#
# <p>L'IFB rassemble 30 plateformes</p>
#
# <ul>
# 	<li><a href="/fr/expertise">Domaines d'expertise</a></li>
# 	<li><a href="/fr/extractions/acceuil">Indicateurs 2018</a></li>
# 	<li><a href="/fr/carte">Répartition géographique</a></li>
# </ul>
# </div>  </div>
# </div>
#   </div>
# </div>
#   </div>
# </div>
#
# <div  data-showblocktitle="1" data-class="" data-width="6" data-hidewcol="" id="tb-megamenu-column-2" class="tb-megamenu-column span6  mega-col-nav">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#         <div  data-type="block" data-block="block--26" class="tb-megamenu-block tb-block tb-megamenu-block">
#   <div class="block-inner">
#     <div id="block-block-26" class="block block-block">
#
#
#   <div class="content">
#     <div class="sous-menu sous-menu--plateforms_regions"><a href="/fr/elixir-fr">Elixir-FR</a>
# <p>IFB est le nœud français d' Elixir</p>
# </div>
#
# <div class="sous-menu sous-menu--plateforms_expertise"><a href="/fr/liste-des-offres">Offres d'emploi</a>
# <p>Consultez les offres d'emploi du réseau IFB</p>
# </div>
#
# <div class="sous-menu sous-menu--cloud"><a href="/fr/actions-en-cours">Feuille de route 2018-2021</a>
# <p>Organisé autour de 16 actions regroupées en 4 lots de travaux</p>
# </div>
#   </div>
# </div>
#   </div>
# </div>
#   </div>
# </div>
# </div>
#   </div>
# </div>
# </li>
#
# <li  data-id="4211" data-level="1" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="left" data-group="0" data-hidewcol="0" data-hidesub="0" class="tb-megamenu-item level-1 mega mega-align-left dropdown">
#   <a href="/fr/services"  class="dropdown-toggle" title="Services utilisateurs">
#
#     Services utilisateurs          <span class="caret"></span>
#           </a>
#   <div  data-class="" data-width="500" style="width: 500px;" class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child">
#   <div class="mega-dropdown-inner">
#     <div  class="tb-megamenu-row row-fluid">
#   <div  data-showblocktitle="1" data-class="" data-width="12" data-hidewcol="" id="tb-megamenu-column-3" class="tb-megamenu-column span12  mega-col-nav">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#         <div  data-type="block" data-block="block--18" class="tb-megamenu-block tb-block tb-megamenu-block">
#   <div class="block-inner">
#     <div id="block-block-18" class="block block-block">
#
#
#   <div class="content">
#     <div class="sous-menu sous-menu--cloud"><a href="/fr/infrastructure-0">Infrastructure IT</a>
# <p>Accès aux services de calcul et stockage de données dédiés aux sciences du vivant</p>
# </div>
#
# <div class="sous-menu sous-menu--formations_cloud_avenir"><a href="/fr/formations-wp">Formations</a>
#     <ul>
#         <li><a href="/fr/formations">Formations à venir</a></li>
#         <li><a href="/fr/past_events">Formations passés</a></li>
#         <li><a href="/fr/soumettre-sa-demande-soutien-pour-formation">Demande de soutien de l’IFB pour une formation</a></li>
#     </ul>
# </div>
#
# <div class="sous-menu sous-menu--donnees"><a href="/fr/services/appui">Accompagnement pour un projet?</a>
#    <ul>
# <!--
#         <li><a href="/fr/conception-projets-collaboratifs">Conception de projets collaboratifs</a></li>
#         <li><a href="/fr/analyse-vos-donnees">Analyse de vos données</a></li>
# -->
#         <li><a href="/fr/soutiens">Aide financière ou logistique</a></li>
#     </ul>
# </div>
#
# <div class="sous-menu sous-menu--apropos_partners"><a href="/fr/industrie">Vous êtes un industriel?</a>
# </div>
#
#   </div>
# </div>
#   </div>
# </div>
#   </div>
# </div>
# </div>
#   </div>
# </div>
# </li>
#
# <li  data-id="4212" data-level="1" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="left" data-group="0" data-hidewcol="0" data-hidesub="0" class="tb-megamenu-item level-1 mega mega-align-left dropdown">
#   <a href="/fr/innovation"  class="dropdown-toggle" title="Innovation">
#
#     Innovation          <span class="caret"></span>
#           </a>
#   <div  data-class="" data-width="350" style="width: 350px;" class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child">
#   <div class="mega-dropdown-inner">
#     <div  class="tb-megamenu-row row-fluid">
#   <div  data-showblocktitle="1" data-class="" data-width="12" data-hidewcol="" id="tb-megamenu-column-4" class="tb-megamenu-column span12  mega-col-nav">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#         <div  data-type="block" data-block="block--38" class="tb-megamenu-block tb-block tb-megamenu-block">
#   <div class="block-inner">
#     <div id="block-block-38" class="block block-block">
#
#
#   <div class="content">
#     <div class="sous-menu sous-menu--apropos_appels"><a href="/fr/projets-pilotes">Projets pilotes</a></div>
# <div class="sous-menu sous-menu--plateform"><a href="/fr/appel-à-défis">Appel à défis</a></div>
# <div class="sous-menu sous-menu--donnees"><a href="/fr/interopérabilité">Interopérabilité</a></div>
#   </div>
# </div>
#   </div>
# </div>
#   </div>
# </div>
# </div>
#   </div>
# </div>
# </li>
#
# <li  data-id="6387" data-level="1" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="left" data-group="0" data-hidewcol="0" data-hidesub="0" class="tb-megamenu-item level-1 mega mega-align-left dropdown">
#   <a href="/fr/ressources"  class="dropdown-toggle" title="Ressources IFB">
#
#     Ressources          <span class="caret"></span>
#           </a>
#   <div  data-class="" data-width="350" style="width: 350px;" class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child">
#   <div class="mega-dropdown-inner">
#     <div  class="tb-megamenu-row row-fluid">
#   <div  data-showblocktitle="1" data-class="" data-width="12" data-hidewcol="" id="tb-megamenu-column-5" class="tb-megamenu-column span12  mega-col-nav">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#         <div  data-type="block" data-block="block--19" class="tb-megamenu-block tb-block tb-megamenu-block">
#   <div class="block-inner">
#     <div id="block-block-19" class="block block-block">
#
#
#   <div class="content">
#     <div class="sous-menu sous-menu--formations_support"><a href="/fr/ressources">Ressources</a>
# <p>Recherchez une ressource parmi celles offertes par l'IFB</p>
#     <ul>
#         <li><a href="/fr/expertise">Expertises</a></li>
#         <li><a href="/fr/services/outils">Outils</a></li>
#         <li><a href="/fr/services/donnees">Base de données</a></li>
#         <li><a href="/fr/training_material">Support de formation</a></li>
#         <li><a href="/fr/formations/pf_pro">Archive formations IFB</a></li>
#         <li><a href="/fr/past_events">Evènements passés</a></li>
#         <li><a href="/fr/elearning">E-learning</a></li>
#     </ul>
# </div>
#
#
#   </div>
# </div>
#   </div>
# </div>
#   </div>
# </div>
# </div>
#   </div>
# </div>
# </li>
# </ul>
#       </div>
#   </div>
#   </div>
# </div>
# <div id="block-search-form" class="block block-search">
#
#
#   <div class="content">
#     <form action="/fr/node/286/node_export/json" method="post" id="search-block-form" accept-charset="UTF-8"><div><div class="container-inline">
#       <h2 class="element-invisible">Formulaire de recherche</h2>
#     <div class="icon"><i class="better_search"></i></div><div class="form-item form-type-textfield form-item-search-block-form">
#   <label class="element-invisible" for="edit-search-block-form--2">Rechercher </label>
#  <input title="Indiquer les termes à rechercher" placeholder="rechercher" type="text" id="edit-search-block-form--2" name="search_block_form" value="" size="10" maxlength="128" class="form-text" />
# </div>
# <div class="element-invisible form-actions form-wrapper" id="edit-actions--2"><input type="submit" id="edit-submit--2" name="op" value="Rechercher" class="form-submit" /></div><input type="hidden" name="form_build_id" value="form-AwoPMaIL_bEt_oo5Pm5jPQBIBHCAIOoup5K2j3pBhdc" />
# <input type="hidden" name="form_id" value="search_block_form" />
# </div>
# </div></form>  </div>
# </div>
#   </div>
#             </nav>
#           </div> <!-- fin de .row -->
#           <a href="https://elixir-europe.org/about-us/who-we-are/nodes/france" target="_blank">
# 	   <img id="logoelixir" src="/sites/default/files/elixir_node_france.png"></a>
# 	   <img id="logo-pia" src="/sites/default/files/partner/logo-investissement-d-avenir_0.png">
#   </div>  <!-- fin de .container -->
# </header>
#
#
# <div class="header-inter">
#           <div id="breadcrumb" class="block-body"><p class="element-invisible">Vous êtes ici</p><div class="breadcrumb"><a href="/fr/node/286/node_export/json" class="active">Outils</a></div></div>
#     </div>
#
# <div class="container page-inter">
#   <main class="contenu">
#
#           <div class="region region-content">
#     <div id="block-system-main" class="block block-system">
#
#
#   <div class="content">
#     Vous n'êtes pas autorisé(e) à accéder à cette page.  </div>
# </div>
#   </div>
#
#
#
# <div id="content" class="column"><div class="section">
#                         <a id="main-content"></a>
#                                       <!-- <h2 class="title" id="page-title"> -->
#                             <!-- </h2> -->
#                                                   <div class="tabs">
#                               </div>
#
#
#   </div></div> <!-- /.section, /#content -->
#
#
# <!--   </div> -->
# </main> <!-- /#main, /#main-wrapper -->
#
#
#
#
#
#
# </div>
# <!-- / Container principal -->
#
#
#
# <div style="width:80%; margin:0 auto;"></div>
#
# <!-- /Modification de l'affichage pour les événement -->
# <section class="partenaires">
#  <div class="container">
#     <div class="region region-partenaires">
#     <div id="block-block-16" class="block block-block">
#
#
#   <div class="content">
#     <div class="row">
# <div class="col-md-2b col-sm-3 col-xs-6"><a href="http://www.cea.fr/drf/" rel="nofollow" target="_blank"><img alt="cea" src="/sites/default/files/partner/logo-cea_0.png" /></a></div>
#
# <div class="col-md-2b col-sm-3 col-xs-6"><a href="http://www.cnrs.fr/" rel="nofollow" target="_blank"><img alt="cnrs" src="/sites/default/files/partner/logo-cnrs_0.png" /></a></div>
#
# <div class="col-md-2b col-sm-3 col-xs-6"><a href="http://www.inra.fr/" rel="nofollow" target="_blank"><img alt="inra" src="/sites/default/files/partner/logo-inra_0.png" /></a></div>
#
# <div class="col-md-2b col-sm-3 col-xs-6"><a href="http://www.inria.fr/" rel="nofollow" target="_blank"><img alt="inria" src="/sites/default/files/partner/logo-inria_0.png" /></a></div>
#
# <div class="col-md-2b col-sm-3 col-xs-6"><a href="http://www.inserm.fr/" rel="nofollow" target="_blank"><img alt="inserm" src="/sites/default/files/partner/logo-inserm_0.png" /></a></div>
#
# <div class="col-md-2b col-sm-3 col-xs-6"><a href="http://www.gouvernement.fr/investissements-d-avenir-cgi" rel="nofollow" target="_blank"><img alt="logo-investissements" src="/sites/default/files/partner/logo-investissement-d-avenir_0.png" /></a></div>
# </div>
#   </div>
# </div>
#   </div>
# </div>
#
# </section>
#
#
# <div id="footer" class="clearfix container">
#       <div class="region region-footer-bas">
#     <div id="block-block-10" class="block block-block">
#
#
#   <div class="content">
#     <div>
# <div>
# <div class="rtecenter">
# <div>
# <div>
# <div class="rtecenter">IFB - Institut Français de Bioinformatique ♦ CNRS UMS 3601 ♦ IFB-Core, Génoscope - 2 rue Gaston Crémieux, 91057 - ÉVRY – CEDEX</div>
# <div class="rtecenter">ANR-11-INBS-0013 ♦ <a href="/logo-ifb">Charte graphique</a> ♦ <a href="/fr/mentions-legales">Mentions légales</a> ♦ <a href="/fr/plan-dacces">Plan d'accès</a> ♦ <a href="/fr/credits">Crédits </a>♦ <a href="/fr/guichet-dorientation">Contact</a> </div>
# </div>
# <div> </div>
# </div>
# </div>
# </div>
# <div> </div>
# </div>
#   </div>
# </div>
#   </div>
# </div> <!-- /#footer -->
#
#
# </div></div> <!-- /.section, /#footer-wrapper -->
#
#
# <a href="#" class="scrollup" title="Haut de page"><span class="screen-reader-text">Retour en haut de page</span></a>
#   <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/themes/IFB_3/js/site.js?pteex4"></script>
# <script type="text/javascript" src="https://www.france-bioinformatique.fr/sites/all/modules/flexslider/assets/js/flexslider.load.js?pteex4"></script>
# </body>
# </html>
